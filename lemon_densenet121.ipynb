# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# ============================================================
# STEP 1: CLEAR MEMORY
# ============================================================
import gc
import tensorflow as tf
tf.keras.backend.clear_session()
gc.collect()
print("✅ Memory cleared!")

# ============================================================
# STEP 2: IMPORTS
# ============================================================
from tensorflow.keras.applications import DenseNet121
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import (EarlyStopping,
                                        ReduceLROnPlateau,
                                        ModelCheckpoint)
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import (accuracy_score, precision_score,
                             recall_score, f1_score,
                             classification_report, confusion_matrix)
import seaborn as sns
import os
import shutil

print("TensorFlow:", tf.__version__)
print("GPU:", tf.config.list_physical_devices('GPU'))

# ============================================================
# STEP 3: PATHS
# ============================================================
ORIGINAL_PATH = "/content/drive/MyDrive/lemon/Original Dataset"

print("\nClasses:", sorted(os.listdir(ORIGINAL_PATH)))

print("\n--- Image counts ---")
total_images = 0
for cls in sorted(os.listdir(ORIGINAL_PATH)):
    count = len(os.listdir(os.path.join(ORIGINAL_PATH, cls)))
    total_images += count
    print(f"  {cls}: {count} images")
print(f"\nTotal: {total_images} images")

# ============================================================
# STEP 4: SETTINGS
# ============================================================
IMG_SIZE    = (224, 224)
BATCH_SIZE  = 16
SEED        = 42
NUM_CLASSES = 9

# ============================================================
# STEP 5: COPY TO LOCAL DISK
# ============================================================
LOCAL_ORIG = "/content/Original_dataset"

if not os.path.exists(LOCAL_ORIG):
    print("\nCopying dataset to local disk...")
    shutil.copytree(ORIGINAL_PATH, LOCAL_ORIG)
    print("✅ Dataset copied!")
else:
    print("✅ Already on local disk!")

# ============================================================
# STEP 6: LOAD & SPLIT — 70% Train | 15% Val | 15% Test
# ============================================================
print("\nLoading Original dataset...")

train_ds = tf.keras.utils.image_dataset_from_directory(
    LOCAL_ORIG,
    validation_split=0.30,
    subset="training",
    seed=SEED,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE
)

val_test_ds = tf.keras.utils.image_dataset_from_directory(
    LOCAL_ORIG,
    validation_split=0.30,
    subset="validation",
    seed=SEED,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE
)

# Split val_test 50/50
total_val_test = tf.data.experimental.cardinality(val_test_ds).numpy()
val_size       = total_val_test // 2

val_ds  = val_test_ds.take(val_size)
test_ds = val_test_ds.skip(val_size)

class_names = train_ds.class_names
print(f"\nClasses ({len(class_names)}):", class_names)

train_batches = tf.data.experimental.cardinality(train_ds).numpy()
val_batches   = tf.data.experimental.cardinality(val_ds).numpy()
test_batches  = tf.data.experimental.cardinality(test_ds).numpy()

print(f"\nTrain batches : {train_batches} (~{train_batches * BATCH_SIZE} images)")
print(f"Val batches   : {val_batches}   (~{val_batches   * BATCH_SIZE} images)")
print(f"Test batches  : {test_batches}  (~{test_batches  * BATCH_SIZE} images)")

# ============================================================
# STEP 7: AUGMENTATION
# ============================================================
augmentation = tf.keras.Sequential([
    tf.keras.layers.RandomFlip("horizontal_and_vertical"),
    tf.keras.layers.RandomRotation(0.3),
    tf.keras.layers.RandomZoom(0.2),
    tf.keras.layers.RandomBrightness(0.2),
    tf.keras.layers.RandomContrast(0.2),
], name="augmentation")

train_ds = train_ds.map(
    lambda x, y: (augmentation(x, training=True), y),
    num_parallel_calls=tf.data.AUTOTUNE
)

# ============================================================
# STEP 8: OPTIMIZATION
# ============================================================
AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.shuffle(500).prefetch(buffer_size=AUTOTUNE)
val_ds   = val_ds.prefetch(buffer_size=AUTOTUNE)
test_ds  = test_ds.prefetch(buffer_size=AUTOTUNE)

# ============================================================
# STEP 9: BUILD DENSENET121
# ============================================================
base_model = DenseNet121(
    weights='imagenet',
    include_top=False,
    input_shape=(224, 224, 3)
)
base_model.trainable = False  # Frozen

print(f"\nDenseNet121 loaded!")
print(f"Total layers: {len(base_model.layers)}")

# Build model
inputs = tf.keras.Input(shape=(224, 224, 3))

# DenseNet121 preprocessing
x = tf.keras.applications.densenet.preprocess_input(inputs)
x = base_model(x, training=False)
x = layers.GlobalAveragePooling2D()(x)
x = layers.BatchNormalization()(x)
x = layers.Dropout(0.4)(x)
x = layers.Dense(256, activation='relu')(x)
x = layers.BatchNormalization()(x)
x = layers.Dropout(0.3)(x)
outputs = layers.Dense(NUM_CLASSES, activation='softmax')(x)

model_densenet = models.Model(inputs, outputs)
model_densenet.summary()

# Confirm frozen
total     = model_densenet.count_params()
trainable = sum([tf.size(w).numpy()
                 for w in model_densenet.trainable_weights])
frozen    = total - trainable
print(f"\nTotal params    : {total:,}")
print(f"Trainable params: {trainable:,}  ← Your head")
print(f"Frozen params   : {frozen:,}  ← DenseNet121 base")
print(f"% Frozen        : {frozen/total*100:.1f}%")

# ============================================================
# STEP 10: COMPILE
# ============================================================
model_densenet.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# ============================================================
# STEP 11: CALLBACKS
# ============================================================
checkpoint_path = '/content/drive/MyDrive/lemon/best_densenet121_original.keras'

callbacks = [
    EarlyStopping(
        monitor='val_accuracy',
        patience=7,
        restore_best_weights=True,
        verbose=1
    ),
    ReduceLROnPlateau(
        monitor='val_loss',
        patience=3,
        factor=0.2,
        min_lr=1e-7,
        verbose=1
    ),
    ModelCheckpoint(
        filepath=checkpoint_path,
        monitor='val_accuracy',
        save_best_only=True,
        verbose=1
    )
]

# ============================================================
# STEP 12: TRAIN
# ============================================================
print("\n" + "="*50)
print("TRAINING DENSENET121 (Original Dataset Only)...")
print("Split: 70% Train | 15% Val | 15% Test")
print("="*50)

history = model_densenet.fit(
    train_ds,
    validation_data=val_ds,
    epochs=50,
    callbacks=callbacks
)

# ============================================================
# STEP 13: PLOT HISTORY
# ============================================================
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

ax1.plot(history.history['accuracy'],     'b-', label='Train Accuracy')
ax1.plot(history.history['val_accuracy'], 'r-', label='Val Accuracy')
ax1.set_title('DenseNet121 (Original) — Accuracy', fontweight='bold')
ax1.set_xlabel('Epoch'); ax1.set_ylabel('Accuracy')
ax1.legend(); ax1.grid(True, alpha=0.3)

ax2.plot(history.history['loss'],     'b-', label='Train Loss')
ax2.plot(history.history['val_loss'], 'r-', label='Val Loss')
ax2.set_title('DenseNet121 (Original) — Loss', fontweight='bold')
ax2.set_xlabel('Epoch'); ax2.set_ylabel('Loss')
ax2.legend(); ax2.grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig('/content/drive/MyDrive/lemon/densenet121_original_history.png', dpi=150)
plt.show()

# ============================================================
# STEP 14: EVALUATE ON TEST SET
# ============================================================
print("\n" + "="*50)
print("EVALUATING ON TEST SET (15% Original)...")
print("="*50)

y_true, y_pred = [], []
for images, labels in test_ds:
    preds = model_densenet.predict(images, verbose=0)
    y_pred.extend(np.argmax(preds, axis=1))
    y_true.extend(labels.numpy())

y_true = np.array(y_true)
y_pred = np.array(y_pred)

acc  = accuracy_score(y_true, y_pred)
prec = precision_score(y_true, y_pred, average='macro', zero_division=0)
rec  = recall_score(y_true, y_pred, average='macro', zero_division=0)
f1   = f1_score(y_true, y_pred, average='macro', zero_division=0)

print(f"\n{'='*40}")
print(f"  DenseNet121 — Original Dataset")
print(f"{'='*40}")
print(f"  Accuracy : {acc:.4f} ({acc*100:.2f}%)")
print(f"  Precision: {prec:.4f} ({prec*100:.2f}%)")
print(f"  Recall   : {rec:.4f} ({rec*100:.2f}%)")
print(f"  F1-Score : {f1:.4f} ({f1*100:.2f}%)")
print(f"{'='*40}")

print("\nClassification Report:")
print(classification_report(y_true, y_pred, target_names=class_names))

# ============================================================
# STEP 15: CONFUSION MATRIX
# ============================================================
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(12, 10))
sns.heatmap(cm, annot=True, fmt='d', cmap='Purples',
            xticklabels=class_names,
            yticklabels=class_names)
plt.title('DenseNet121 (Original) — Confusion Matrix',
          fontsize=14, fontweight='bold')
plt.ylabel('True Label', fontsize=12)
plt.xlabel('Predicted Label', fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.savefig('/content/drive/MyDrive/lemon/densenet121_original_cm.png', dpi=150)
plt.show()

# ============================================================
# STEP 16: SAVE MODEL & RESULTS
# ============================================================
model_densenet.save('/content/drive/MyDrive/lemon/densenet121_original_final.keras')

results_text = f"""
DenseNet121 — Original Dataset Only
========================================
Dataset     : Original (1,354 images)
Split       : 70% Train | 15% Val | 15% Test
Augmentation: Runtime augmentation applied
========================================
Accuracy : {acc:.4f} ({acc*100:.2f}%)
Precision: {prec:.4f} ({prec*100:.2f}%)
Recall   : {rec:.4f} ({rec*100:.2f}%)
F1-Score : {f1:.4f} ({f1*100:.2f}%)
========================================
"""

with open('/content/drive/MyDrive/lemon/densenet121_original_results.txt', 'w') as f:
    f.write(results_text)

print(results_text)

# ============================================================
# STEP 17: COMPARISON TABLE SO FAR
# ============================================================
print("\n" + "="*55)
print("  RESULTS COMPARISON — Original Dataset")
print("="*55)
print(f"  {'Model':<20} {'Accuracy':>10} {'F1-Score':>10}")
print("-"*55)
print(f"  {'EfficientNetB3':<20} {'?':>10} {'?':>10}  ← run earlier")
print(f"  {'DenseNet121':<20} {acc*100:>9.2f}% {f1*100:>9.2f}%")
print("="*55)

# Clear memory
del model_densenet
tf.keras.backend.clear_session()
gc.collect()
print("\n✅ Memory cleared!")
print("✅ All DenseNet121 outputs saved to Drive!")
# Out:
# ✅ Memory cleared!
# TensorFlow: 2.19.0
# GPU: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
#
# Classes: ['Anthracnose', 'Bacterial Blight', 'Citrus Canker', 'Curl Virus', 'Deficiency Leaf', 'Dry Leaf', 'Healthy Leaf', 'Sooty Mould', 'Spider Mites']
#
# --- Image counts ---
#   Anthracnose: 100 images
#   Bacterial Blight: 105 images
#   Citrus Canker: 178 images
#   Curl Virus: 115 images
#   Deficiency Leaf: 193 images
#   Dry Leaf: 186 images
#   Healthy Leaf: 210 images
#   Sooty Mould: 153 images
#   Spider Mites: 114 images
#
# Total: 1354 images
#
# Copying dataset to local disk...
# ✅ Dataset copied!
#
# Loading Original dataset...
# Found 1354 files belonging to 9 classes.
# Using 948 files for training.
# Found 1354 files belonging to 9 classes.
# Using 406 files for validation.
#
# Classes (9): ['Anthracnose', 'Bacterial Blight', 'Citrus Canker', 'Curl Virus', 'Deficiency Leaf', 'Dry Leaf', 'Healthy Leaf', 'Sooty Mould', 'Spider Mites']
#
# Train batches : 60 (~960 images)
# Val batches   : 13   (~208 images)
# Test batches  : 13  (~208 images)
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29084464/29084464 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step
#
# DenseNet121 loaded!
# Total layers: 427
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ true_divide (TrueDivide)        │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ add (Add)                       │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ true_divide_1 (TrueDivide)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ densenet121 (Functional)        │ (None, 7, 7, 1024)     │     7,037,504 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 1024)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 1024)           │         4,096 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       262,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 9)              │         2,313 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 7,307,337 (27.88 MB)
#  Trainable params: 267,273 (1.02 MB)
#  Non-trainable params: 7,040,064 (26.86 MB)
# Total params    : 7,307,337
# Trainable params: 267,273  ← Your head
# Frozen params   : 7,040,064  ← DenseNet121 base
# % Frozen        : 96.3%
#
# ==================================================
# TRAINING DENSENET121 (Original Dataset Only)...
# Split: 70% Train | 15% Val | 15% Test
# ==================================================
# Epoch 1/50
# 59/60 ━━━━━━━━━━━━━━━━━━━━ 0s 296ms/step - accuracy: 0.4611 - loss: 1.7378
# Epoch 1: val_accuracy improved from None to 0.78365, saving model to /content/drive/MyDrive/lemon/best_densenet121_original.keras
#
# Epoch 1: finished saving model to /content/drive/MyDrive/lemon/best_densenet121_original.keras
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 78s 561ms/step - accuracy: 0.6667 - loss: 1.0247 - val_accuracy: 0.7837 - val_loss: 0.6143 - learning_rate: 0.0010
# Epoch 2/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8534 - loss: 0.4147
# Epoch 2: val_accuracy improved from 0.78365 to 0.87500, saving model to /content/drive/MyDrive/lemon/best_densenet121_original.keras
#
# Epoch 2: finished saving model to /content/drive/MyDrive/lemon/best_densenet121_original.keras
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 20s 88ms/step - accuracy: 0.8639 - loss: 0.4181 - val_accuracy: 0.8750 - val_loss: 0.3043 - learning_rate: 0.0010
# Epoch 3/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8693 - loss: 0.3708
# Epoch 3: val_accuracy improved from 0.87500 to 0.92308, saving model to /content/drive/MyDrive/lemon/best_densenet121_original.keras
#
# Epoch 3: finished saving model to /content/drive/MyDrive/lemon/best_densenet121_original.keras
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 20s 84ms/step - accuracy: 0.8819 - loss: 0.3277 - val_accuracy: 0.9231 - val_loss: 0.2168 - learning_rate: 0.0010
# Epoch 4/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.9181 - loss: 0.2628
# Epoch 4: val_accuracy improved from 0.92308 to 0.95192, saving model to /content/drive/MyDrive/lemon/best_densenet121_original.keras
#
# Epoch 4: finished saving model to /content/drive/MyDrive/lemon/best_densenet121_original.keras
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 20s 82ms/step - accuracy: 0.9219 - loss: 0.2345 - val_accuracy: 0.9519 - val_loss: 0.1798 - learning_rate: 0.0010
# Epoch 5/50
# 59/60 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9216 - loss: 0.2367
# Epoch 5: val_accuracy did not improve from 0.95192
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 18s 58ms/step - accuracy: 0.9188 - loss: 0.2454 - val_accuracy: 0.9471 - val_loss: 0.1554 - learning_rate: 0.0010
# Epoch 6/50
# 59/60 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9038 - loss: 0.3045
# Epoch 6: val_accuracy improved from 0.95192 to 0.96635, saving model to /content/drive/MyDrive/lemon/best_densenet121_original.keras
#
# Epoch 6: finished saving model to /content/drive/MyDrive/lemon/best_densenet121_original.keras
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 20s 83ms/step - accuracy: 0.9188 - loss: 0.2358 - val_accuracy: 0.9663 - val_loss: 0.1212 - learning_rate: 0.0010
# Epoch 7/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.9548 - loss: 0.1542
# Epoch 7: val_accuracy improved from 0.96635 to 0.97115, saving model to /content/drive/MyDrive/lemon/best_densenet121_original.keras
#
# Epoch 7: finished saving model to /content/drive/MyDrive/lemon/best_densenet121_original.keras
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 20s 82ms/step - accuracy: 0.9462 - loss: 0.1778 - val_accuracy: 0.9712 - val_loss: 0.0926 - learning_rate: 0.0010
# Epoch 8/50
# 59/60 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9296 - loss: 0.2237
# Epoch 8: val_accuracy improved from 0.97115 to 0.97596, saving model to /content/drive/MyDrive/lemon/best_densenet121_original.keras
#
# Epoch 8: finished saving model to /content/drive/MyDrive/lemon/best_densenet121_original.keras
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 20s 81ms/step - accuracy: 0.9335 - loss: 0.2012 - val_accuracy: 0.9760 - val_loss: 0.0818 - learning_rate: 0.0010
# Epoch 9/50
# 59/60 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9616 - loss: 0.1242
# Epoch 9: val_accuracy did not improve from 0.97596
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 20s 84ms/step - accuracy: 0.9578 - loss: 0.1424 - val_accuracy: 0.9663 - val_loss: 0.1147 - learning_rate: 0.0010
# Epoch 10/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9453 - loss: 0.1459
# Epoch 10: val_accuracy did not improve from 0.97596
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 19s 60ms/step - accuracy: 0.9409 - loss: 0.1608 - val_accuracy: 0.9712 - val_loss: 0.0623 - learning_rate: 0.0010
# Epoch 11/50
# 59/60 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.9565 - loss: 0.1530
# Epoch 11: val_accuracy did not improve from 0.97596
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 19s 64ms/step - accuracy: 0.9515 - loss: 0.1649 - val_accuracy: 0.9615 - val_loss: 0.0834 - learning_rate: 0.0010
# Epoch 12/50
# 59/60 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.9693 - loss: 0.1097
# Epoch 12: val_accuracy improved from 0.97596 to 0.98077, saving model to /content/drive/MyDrive/lemon/best_densenet121_original.keras
#
# Epoch 12: finished saving model to /content/drive/MyDrive/lemon/best_densenet121_original.keras
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 21s 97ms/step - accuracy: 0.9473 - loss: 0.1626 - val_accuracy: 0.9808 - val_loss: 0.0720 - learning_rate: 0.0010
# Epoch 13/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9543 - loss: 0.1370
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 13: val_accuracy did not improve from 0.98077
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 18s 61ms/step - accuracy: 0.9546 - loss: 0.1416 - val_accuracy: 0.9567 - val_loss: 0.1103 - learning_rate: 0.0010
# Epoch 14/50
# 59/60 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9454 - loss: 0.1557
# Epoch 14: val_accuracy did not improve from 0.98077
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 18s 59ms/step - accuracy: 0.9557 - loss: 0.1402 - val_accuracy: 0.9760 - val_loss: 0.0716 - learning_rate: 2.0000e-04
# Epoch 15/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9593 - loss: 0.1376
# Epoch 15: val_accuracy did not improve from 0.98077
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 18s 59ms/step - accuracy: 0.9568 - loss: 0.1436 - val_accuracy: 0.9712 - val_loss: 0.0800 - learning_rate: 2.0000e-04
# Epoch 16/50
# 59/60 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.9631 - loss: 0.1274
# Epoch 16: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
#
# Epoch 16: val_accuracy did not improve from 0.98077
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 19s 74ms/step - accuracy: 0.9599 - loss: 0.1399 - val_accuracy: 0.9760 - val_loss: 0.0679 - learning_rate: 2.0000e-04
# Epoch 17/50
# 59/60 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.9625 - loss: 0.1037
# Epoch 17: val_accuracy did not improve from 0.98077
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 20s 60ms/step - accuracy: 0.9578 - loss: 0.1088 - val_accuracy: 0.9760 - val_loss: 0.0736 - learning_rate: 4.0000e-05
# Epoch 18/50
# 59/60 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9691 - loss: 0.1090
# Epoch 18: val_accuracy did not improve from 0.98077
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 18s 63ms/step - accuracy: 0.9610 - loss: 0.1305 - val_accuracy: 0.9760 - val_loss: 0.0764 - learning_rate: 4.0000e-05
# Epoch 19/50
# 59/60 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9507 - loss: 0.1430
# Epoch 19: val_accuracy did not improve from 0.98077
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 21s 76ms/step - accuracy: 0.9504 - loss: 0.1407 - val_accuracy: 0.9808 - val_loss: 0.0601 - learning_rate: 4.0000e-05
# Epoch 19: early stopping
# Restoring model weights from the end of the best epoch: 12.
# ==================================================
# EVALUATING ON TEST SET (15% Original)...
# ==================================================
#
# ========================================
#   DenseNet121 — Original Dataset
# ========================================
#   Accuracy : 0.9798 (97.98%)
#   Precision: 0.9676 (96.76%)
#   Recall   : 0.9825 (98.25%)
#   F1-Score : 0.9731 (97.31%)
# ========================================
#
# Classification Report:
#                   precision    recall  f1-score   support
#
#      Anthracnose       0.92      1.00      0.96        12
# Bacterial Blight       0.79      1.00      0.88        11
#    Citrus Canker       1.00      1.00      1.00        22
#       Curl Virus       1.00      1.00      1.00        16
#  Deficiency Leaf       1.00      0.94      0.97        32
#         Dry Leaf       1.00      1.00      1.00        34
#     Healthy Leaf       1.00      1.00      1.00        35
#      Sooty Mould       1.00      0.90      0.95        21
#     Spider Mites       1.00      1.00      1.00        15
#
#         accuracy                           0.98       198
#        macro avg       0.97      0.98      0.97       198
#     weighted avg       0.98      0.98      0.98       198
# DenseNet121 — Original Dataset Only
# ========================================
# Dataset     : Original (1,354 images)
# Split       : 70% Train | 15% Val | 15% Test
# Augmentation: Runtime augmentation applied
# ========================================
# Accuracy : 0.9798 (97.98%)
# Precision: 0.9676 (96.76%)
# Recall   : 0.9825 (98.25%)
# F1-Score : 0.9731 (97.31%)
# ========================================
#
#
# =======================================================
#   RESULTS COMPARISON — Original Dataset
# =======================================================
#   Model                  Accuracy   F1-Score
# -------------------------------------------------------
#   EfficientNetB3                ?          ?  ← run earlier
#   DenseNet121              97.98%     97.31%
# =======================================================
#
# ✅ Memory cleared!
# ✅ All DenseNet121 outputs saved to Drive!
